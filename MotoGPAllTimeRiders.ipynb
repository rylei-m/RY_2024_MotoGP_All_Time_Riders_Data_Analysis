# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

# %%
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("/home/rylei/Fall2024/Pers/RY_2024_MotoGP_All_Time_Riders_Data_Analysis/motogp_allriders.csv", engine="python",encoding='latin-1')

# %% [raw]
# df.head(5)

# %%
top_20 = df.iloc[:20]
top_20.shape
# Out:
# (20, 7)

# %%
f, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="World Championships", y="Name", data=top_20,
            label="World Championships", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100), ylabel="",
       xlabel="Top 20 MotoGP riders of all time.")
sns.despine(left=True, bottom=True)

# %%
a, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="victories", y="Name", data=top_20,
            label="1st Place", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100),ylabel="",
       xlabel="Victories of Top 20 Riders")
sns.despine(left=True, bottom=True)

# %%
a, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="2nd places", y="Name", data=top_20,
            label="2nd Place", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100),ylabel="",
       xlabel="2nd Place Finishes of Top 20 Riders")
sns.despine(left=True, bottom=True)

# %%
a, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="3rd places", y="Name", data=top_20,
            label="3rd Place", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100),ylabel="",
       xlabel="3rd Place Finishes of Top 20 Riders")
sns.despine(left=True, bottom=True)

# %%
a, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="pole positions from '74 to 2021", y="Name", data=top_20,
            label="Pole Positions", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100),ylabel="",
       xlabel="Pole Positions of Top 20 Riders from 1974 to 2021")
sns.despine(left=True, bottom=True)

# %%
a, ax = plt.subplots(figsize=(16,9))

sns.set_color_codes("pastel")
sns.barplot(x="race fastest lap to 2021", y="Name", data=top_20,
            label="Pole Positions", color="b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,100),ylabel="",
       xlabel="Fastest Lap of Top 20 Riders to 2021")
sns.despine(left=True, bottom=True)
